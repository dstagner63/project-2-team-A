# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# The path to the World Happiness CSV file
shelters_file = "data/petfinder_shelters.csv"

# Read the World Happiness data into pandas
original_shelters_df = pd.read_csv(shelters_file, delimiter = ';')
original_shelters_df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-127103b1c0d9> in <module>
#       3
#       4 # Read the World Happiness data into pandas
# ----> 5 original_shelters_df = pd.read_csv(shelters_file, delimiter = ';')
#       6 original_shelters_df
#
# ~\anaconda3\envs\bcs\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\envs\bcs\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\anaconda3\envs\bcs\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\anaconda3\envs\bcs\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 1624, saw 2

# %%
# Inspect the data types
original_happiness_df.dtypes
# Out:
# Country name                                                 object
# Year                                                          int64
# Life Ladder                                                 float64
# Log GDP per capita                                          float64
# Social support                                              float64
# Healthy life expectancy at birth                            float64
# Freedom to make life choices                                float64
# Generosity                                                  float64
# Perceptions of corruption                                   float64
# Positive affect                                             float64
# Negative affect                                             float64
# Confidence in national government                           float64
# Democratic Quality                                          float64
# Delivery Quality                                            float64
# Standard deviation of ladder by country-year                float64
# Standard deviation/Mean of ladder by country-year           float64
# GINI index (World Bank estimate)                            float64
# GINI index (World Bank estimate), average 2000-16           float64
# gini of household income reported in Gallup, by wp5-year    float64
# Most people can be trusted, Gallup                          float64
# Most people can be trusted, WVS round 1981-1984             float64
# Most people can be trusted, WVS round 1989-1993             float64
# Most people can be trusted, WVS round 1994-1998             float64
# Most people can be trusted, WVS round 1999-2004             float64
# Most people can be trusted, WVS round 2005-2009             float64
# Most people can be trusted, WVS round 2010-2014             float64
# dtype: object

# %%
# Create a pandas DataFrame
clean_happiness_df = pd.DataFrame(original_happiness_df)
clean_happiness_df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# 4                            52.240002                      0.530935
# ...                                ...                           ...
# 1699                         52.380001                      0.642034
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 0       0.177889                   0.881686         0.517637  ...
# 1       0.200178                   0.850035         0.583926  ...
# 2       0.134353                   0.706766         0.618265  ...
# 3       0.172137                   0.731109         0.611387  ...
# 4       0.244273                   0.775620         0.710385  ...
# ...          ...                        ...              ...  ...
# 1699   -0.048634                   0.820217         0.725214  ...
# 1700   -0.097354                   0.810457         0.715079  ...
# 1701   -0.068105                   0.723612         0.737636  ...
# 1702   -0.069670                   0.751208         0.806428  ...
# 1703   -0.038384                   0.844209         0.710119  ...
#
#       GINI index (World Bank estimate)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 1699                               NaN
# 1700                               NaN
# 1701                               NaN
# 1702                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1699                                              0.432
# 1700                                              0.432
# 1701                                              0.432
# 1702                                              0.432
# 1703                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 0                                                   NaN
# 1                                              0.441906
# 2                                              0.327318
# 3                                              0.336764
# 4                                              0.344540
# ...                                                 ...
# 1699                                           0.601080
# 1700                                           0.655137
# 1701                                           0.596690
# 1702                                           0.581484
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 0                                    NaN
# 1                               0.286315
# 2                               0.275833
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1699                                 NaN
# 1700                                 NaN
# 1701                                 NaN
# 1702                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                         0.116683
# 1700                                         0.116683
# 1701                                         0.116683
# 1702                                         0.116683
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1699                                         0.082942
# 1700                                         0.082942
# 1701                                         0.082942
# 1702                                         0.082942
# 1703                                         0.082942
#
# [1704 rows x 26 columns]

# %%
# Filter the DataFrame to only the year 2010
clean_happiness_df = clean_happiness_df.loc[clean_happiness_df["Year"] == 2010, :]
clean_happiness_df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 13        Albania  2010     5.268937            9.203032        0.733152
# 22        Algeria  2010     5.463567            9.462701             NaN
# 37      Argentina  2010     6.441067            9.836924        0.926799
# 50        Armenia  2010     4.367811            8.810287        0.660342
# ...           ...   ...          ...                 ...             ...
# 1633   Uzbekistan  2010     5.095342            8.352248        0.903226
# 1646    Venezuela  2010     7.478455            9.713838        0.931576
# 1659      Vietnam  2010     5.295781            8.391214        0.786611
# 1670        Yemen  2010     4.350313            8.407098        0.726612
# 1695     Zimbabwe  2010     4.681570            7.296330        0.856638
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2                            51.599998                      0.600127
# 13                           66.400002                      0.568958
# 22                           64.500000                      0.592696
# 37                           67.300003                      0.730258
# 50                           65.199997                      0.459257
# ...                                ...                           ...
# 1633                         63.200001                           NaN
# 1646                         65.699997                      0.768257
# 1659                         66.500000                      0.831494
# 1670                         54.299999                      0.659284
# 1695                         46.700001                      0.664718
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 2       0.134353                   0.706766         0.618265  ...
# 13     -0.175367                   0.726262         0.647908  ...
# 22     -0.229078                   0.618038              NaN  ...
# 37     -0.121725                   0.854695         0.846136  ...
# 50     -0.162075                   0.890629         0.509669  ...
# ...          ...                        ...              ...  ...
# 1633   -0.031256                   0.518720         0.775874  ...
# 1646   -0.166679                   0.754269         0.861522  ...
# 1659   -0.003416                   0.742637         0.685243  ...
# 1670   -0.108985                   0.853403         0.582427  ...
# 1695   -0.066457                   0.828361         0.747702  ...
#
#       GINI index (World Bank estimate)  \
# 2                                  NaN
# 13                                 NaN
# 22                                 NaN
# 37                               0.430
# 50                               0.300
# ...                                ...
# 1633                               NaN
# 1646                               NaN
# 1659                             0.393
# 1670                               NaN
# 1695                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 2                                                   NaN
# 13                                             0.303250
# 22                                             0.276000
# 37                                             0.460938
# 50                                             0.319250
# ...                                                 ...
# 1633                                           0.348000
# 1646                                           0.497167
# 1659                                           0.362750
# 1670                                           0.357000
# 1695                                           0.432000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 2                                              0.327318
# 13                                             0.543528
# 22                                             0.492713
# 37                                             0.366742
# 50                                             0.385238
# ...                                                 ...
# 1633                                           0.330614
# 1646                                           0.313196
# 1659                                           0.479870
# 1670                                           0.403628
# 1695                                           0.680030
#
#       Most people can be trusted, Gallup  \
# 2                               0.275833
# 13                              0.201118
# 22                                   NaN
# 37                              0.228952
# 50                                   NaN
# ...                                  ...
# 1633                                 NaN
# 1646                            0.129567
# 1659                            0.269085
# 1670                                 NaN
# 1695                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 2                                                 NaN
# 13                                                NaN
# 22                                                NaN
# 37                                           0.270073
# 50                                                NaN
# ...                                               ...
# 1633                                              NaN
# 1646                                              NaN
# 1659                                              NaN
# 1670                                              NaN
# 1695                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 2                                                 NaN
# 13                                                NaN
# 22                                                NaN
# 37                                           0.223553
# 50                                                NaN
# ...                                               ...
# 1633                                              NaN
# 1646                                              NaN
# 1659                                              NaN
# 1670                                              NaN
# 1695                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 2                                                 NaN
# 13                                           0.243243
# 22                                                NaN
# 37                                           0.170844
# 50                                           0.235000
# ...                                               ...
# 1633                                              NaN
# 1646                                         0.133333
# 1659                                              NaN
# 1670                                              NaN
# 1695                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 2                                                 NaN
# 13                                           0.232000
# 22                                           0.107644
# 37                                           0.150154
# 50                                                NaN
# ...                                               ...
# 1633                                              NaN
# 1646                                         0.158333
# 1659                                         0.387000
# 1670                                              NaN
# 1695                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 2                                                 NaN
# 13                                                NaN
# 22                                                NaN
# 37                                           0.174058
# 50                                                NaN
# ...                                               ...
# 1633                                              NaN
# 1646                                              NaN
# 1659                                         0.510054
# 1670                                              NaN
# 1695                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014
# 2                                                 NaN
# 13                                                NaN
# 22                                           0.179286
# 37                                           0.193531
# 50                                           0.109136
# ...                                               ...
# 1633                                         0.139224
# 1646                                              NaN
# 1659                                              NaN
# 1670                                         0.385000
# 1695                                         0.082942
#
# [124 rows x 26 columns]

# %%
# Rename columns to exclude capital letters and spaces in preparation to loading into SQL database.
renamed_happiness_df = clean_happiness_df.rename(columns={"Country name":"country", "Year":"year", 
                                             "Life Ladder":"life_ladder", "Log GDP per capita":"log_gdp_per_capita",
                                            "Social support":"social_support", "Healthy life expectancy at birth":"healthy_life_expectancy_at_birth",
                                              "Freedom to make life choices":"freedom_to_make_life_choices", "Generosity":"generosity",
                                                  "Perceptions of corruption":"perceptions_of_corruption", "Positive affect":"positive_affect",
                                                     "Negative affect":"negative_affect", "GINI index (World Bank estimate)":"gini_index_(world_bank_estimate)",
                                                     "GINI index (World Bank estimate), average 2000-16":"gini_index_(world_bank_estimate),_average_2000-16",
                                                     "gini of household income reported in Gallup, by wp5-year":"gini_of_household_income_reported_in_gallup,_by_wp5-year",
                                                     "Most people can be trusted, Gallup":"most_people_can_be_trusted,_gallup",
                                                     "Most people can be trusted, WVS round 1981-1984":"most_people_can_be_trusted,_wvs_round_1981-1984",
                                                     "Most people can be trusted, WVS round 1989-1993":"most_people_can_be_trusted,_wvs_round_1989-1993",
                                                     "Most people can be trusted, WVS round 1994-1998":"most_people_can_be_trusted,_wvs_round_1994-1998",
                                                     "Most people can be trusted, WVS round 1999-2004":"most_people_can_be_trusted,_wvs_round_1999-2004",
                                                     "Most people can be trusted, WVS round 2005-2009":"most_people_can_be_trusted,_wvs_round_2005-2009",
                                                     "Most people can be trusted, WVS round 2010-2014":"most_people_can_be_trusted,_wvs_round_2010-2014"})

renamed_happiness_df.head()
# Out:
#         country  year  life_ladder  log_gdp_per_capita  social_support  \
# 2   Afghanistan  2010     4.758381            7.386629        0.539075
# 13      Albania  2010     5.268937            9.203032        0.733152
# 22      Algeria  2010     5.463567            9.462701             NaN
# 37    Argentina  2010     6.441067            9.836924        0.926799
# 50      Armenia  2010     4.367811            8.810287        0.660342
#
#     healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 2                          51.599998                      0.600127
# 13                         66.400002                      0.568958
# 22                         64.500000                      0.592696
# 37                         67.300003                      0.730258
# 50                         65.199997                      0.459257
#
#     generosity  perceptions_of_corruption  positive_affect  ...  \
# 2     0.134353                   0.706766         0.618265  ...
# 13   -0.175367                   0.726262         0.647908  ...
# 22   -0.229078                   0.618038              NaN  ...
# 37   -0.121725                   0.854695         0.846136  ...
# 50   -0.162075                   0.890629         0.509669  ...
#
#     gini_index_(world_bank_estimate)  \
# 2                                NaN
# 13                               NaN
# 22                               NaN
# 37                              0.43
# 50                              0.30
#
#     gini_index_(world_bank_estimate),_average_2000-16  \
# 2                                                 NaN
# 13                                           0.303250
# 22                                           0.276000
# 37                                           0.460938
# 50                                           0.319250
#
#     gini_of_household_income_reported_in_gallup,_by_wp5-year  \
# 2                                            0.327318
# 13                                           0.543528
# 22                                           0.492713
# 37                                           0.366742
# 50                                           0.385238
#
#     most_people_can_be_trusted,_gallup  \
# 2                             0.275833
# 13                            0.201118
# 22                                 NaN
# 37                            0.228952
# 50                                 NaN
#
#     most_people_can_be_trusted,_wvs_round_1981-1984  \
# 2                                               NaN
# 13                                              NaN
# 22                                              NaN
# 37                                         0.270073
# 50                                              NaN
#
#     most_people_can_be_trusted,_wvs_round_1989-1993  \
# 2                                               NaN
# 13                                              NaN
# 22                                              NaN
# 37                                         0.223553
# 50                                              NaN
#
#     most_people_can_be_trusted,_wvs_round_1994-1998  \
# 2                                               NaN
# 13                                         0.243243
# 22                                              NaN
# 37                                         0.170844
# 50                                         0.235000
#
#     most_people_can_be_trusted,_wvs_round_1999-2004  \
# 2                                               NaN
# 13                                         0.232000
# 22                                         0.107644
# 37                                         0.150154
# 50                                              NaN
#
#     most_people_can_be_trusted,_wvs_round_2005-2009  \
# 2                                               NaN
# 13                                              NaN
# 22                                              NaN
# 37                                         0.174058
# 50                                              NaN
#
#     most_people_can_be_trusted,_wvs_round_2010-2014
# 2                                               NaN
# 13                                              NaN
# 22                                         0.179286
# 37                                         0.193531
# 50                                         0.109136
#
# [5 rows x 26 columns]

# %%
# Reset the index to country
#happiness_data = renamed_happiness_df.set_index("country")
#happiness_data

# %%
happiness_data = renamed_happiness_df[["country","year","life_ladder","log_gdp_per_capita","social_support", 
                                     "healthy_life_expectancy_at_birth", "freedom_to_make_life_choices", 
                                     "generosity", "perceptions_of_corruption"]]
happiness_data.head()
#happiness_data.dtypes
# Out:
#         country  year  life_ladder  log_gdp_per_capita  social_support  \
# 2   Afghanistan  2010     4.758381            7.386629        0.539075
# 13      Albania  2010     5.268937            9.203032        0.733152
# 22      Algeria  2010     5.463567            9.462701             NaN
# 37    Argentina  2010     6.441067            9.836924        0.926799
# 50      Armenia  2010     4.367811            8.810287        0.660342
#
#     healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 2                          51.599998                      0.600127
# 13                         66.400002                      0.568958
# 22                         64.500000                      0.592696
# 37                         67.300003                      0.730258
# 50                         65.199997                      0.459257
#
#     generosity  perceptions_of_corruption
# 2     0.134353                   0.706766
# 13   -0.175367                   0.726262
# 22   -0.229078                   0.618038
# 37   -0.121725                   0.854695
# 50   -0.162075                   0.890629

# %%
happiness_data.to_csv("data/clean_happiness.csv", index=False, header=True)

# %%
# Connect to local database
engine = create_engine(f'postgresql://postgres:melsie@localhost:5432/happiness_etoh_worldcup')
connection = engine.connect()
#engine.table_names()

# Load happiness csv
happiness_data.to_sql(name='happiness_data', con=engine, if_exists='append', index=False)
